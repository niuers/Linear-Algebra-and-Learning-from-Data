# %% [markdown]
# #### Problem VI.1.1
#
# * For two circular discs, if one is inside another, the union of them is a convex set.
#
# * For two squares, the union is a convex if one is inside another, or if the two have the same length of side, and one side of a square is parallel and falling inside another square.
#
# #### Problem VI.1.2
#
# The test is correct for triangles in $R^2$. It looks correct in $R^3$ as well.
#
#
# #### Problem VI.1.3
#
# For a set $S$ in $R^n$, we can find all the half-spaces that contain it, then take the intersection of the half-spaces. This can be the convex hull for set $S$.
#
# #### Problem VI.1.4
#
# * (a) If $x,y \in K_1\cap K_2$, then $x,y\in K_1$ and $x,y \in K_2$, so any points between $x,y$ will be in $K_1, K_2$ as well, so they belong to $K_1 \cap K_2$, which shows the intersection is also convex
#
# * (b) Since $F_1,F_2$ are convex function, let the set of points on and above each graph be $S_1,S_2$ respectively, and we know that $S_1,S_2$ are convex as well. The intersection of $S_1\cap S_2$ is the set of points on and above the maximum of $F_1,F_2$, i.e. above $F_3$, since the intersection is convex, we see that $F_3$ is convex
#
# #### Problem VI.1.5
#
# The $F$ is not a convex function regardless of how we assign 1 or 0. We can connect some points and find out that the points along the line can fall below $F$.
#
# #### Problem VI.1.6
#
# * (a) $\frac{d^2f}{dx^2} = \frac{1}{x} > 0$ on the domain $x>0$ so the entropy is convex.
# * (b) $\frac{d^2f}{dx^2} = \frac{e^{x+y}}{(e^x+e^y)^2} > 0$, also the second derivative to $y$ is also greater than 0, so the function is convex on all $x,y$
#
# * (c) We need compute the Hessian matrix $H$ for the $l^p$ norm and check if the matrix is poistive semi-definite. We check if the first leading determinant $D_1 > 0$, which is the element $H_{11} = \frac{\partial^2{l^p}}{\partial{x^2_1}}$
#
# We have $\frac{\partial{l^p}}{\partial{x_1}} = \left(|x_1|^p + |x_2|^p\right)^{\frac{1}{p}-1}|x_1|^{p-1}\frac{d|x_1|}{dx_1}$, where $\frac{d|x_1|}{dx_1} = sign(x_1)$, take a second derivative, we have
#
# $\frac{\partial^2{l^p}}{\partial{x^2_1}} = (1-p)\left(|x_1|^p + |x_2|^p\right)^{\frac{1}{p}-2}(\frac{d|x_1|}{dx_1})^2|x_1|^{2p-2} + (p-1)\left(|x_1|^p + |x_2|^p\right)^{\frac{1}{p}-1}(\frac{d|x_1|}{dx_1})^2 |x_1|^{p-2} = (p-1)\left(|x_1|^p + |x_2|^p\right)^{\frac{1}{p}-2}|x_1|^{p-2}|x_2|^p \ge 0$ when $p\ge 1$.
#
# So we need compute other components as well. We have
# $\frac{\partial^2{l^p}}{\partial{x^2_2}} = (1-p)\left(|x_1|^p + |x_2|^p\right)^{\frac{1}{p}-2}(\frac{d|x_2|}{dx_2})^2|x_2|^{2p-2} + (p-1)\left(|x_1|^p + |x_2|^p\right)^{\frac{1}{p}-1}(\frac{d|x_2|}{dx_2})^2 |x_2|^{p-2} = (p-1)\left(|x_1|^p + |x_2|^p\right)^{\frac{1}{p}-2}|x_2|^{p-2}|x_1|^p$.
#
# And $H_{12}=H_{21} = \frac{\partial^2{l^p}}{\partial{x_1}\partial{x_2}} = (1-p)\left(|x_1|^p + |x_2|^p\right)^{\frac{1}{p}-2}|x_1|^{p-1}|x_2|^{p-1}\frac{d|x_1|}{dx_1}\frac{d|x_2|}{dx_2}$
#
# To compute the determinant of $H$, we have
#
# \begin{align*}
# det(H) &= H_{11}H_{22} - H_{12}H_{21} \\
# &= (p-1)^2|x_1|^{2p-2}|x_2|^{2p-2}\left(|x_1|^p + |x_2|^p\right)^{\frac{2}{p}-4} - (1-p)^2|x_1|^{2p-2}|x_2|^{2p-2}\left(|x_1|^p + |x_2|^p\right)^{\frac{2}{p}-4} \\
# &= 0\\
# \end{align*}
#
# So $H$ is positive semi-definite, the norm $l^p$ is convex when $p\ge 1$.
#
# * (d) If $v_1$ is the eigenvector corresponding to $\lambda_1$, then we have $Sv_1 = \lambda_1 v_1$, so $v^T_1 Sv_1 = \lambda_1 v^T_1 v_1$, and $\lambda_1 = \frac{v^T_1 Sv_1}{v^T_1 v_1}$, it's clear the the 2nd derivative w.r.t. $S$ is 0, so $\lambda_1(S)$ is positive semi-definite. It is convex
#
# #### Problem VI.1.7
#
# Take derivative of $R$ w.r.t. $x,y$, we have
#
# $\frac{\partial{R}}{\partial{x}} = \frac{-2xy^2}{(x^2+y^2)^2}$, $\frac{\partial{R}}{\partial{y}} = \frac{2yx^2}{(x^2+y^2)^2}$
#
# The second derivatives are:
#
# $H_{11} = \frac{\partial^2{R}}{\partial{x^2}} = \frac{-2y^2(x^2+y^2)^2 - 2(x^2+y^2)2x(-2xy^2)}{(x^2+y^2)^4} = \frac{(x^2+y^2)y^2\left(-2(x^2+y^2)+8x^2\right) }{(x^2+y^2)^4} = \frac{2y^2\left(3x^2-y^2\right) }{(x^2+y^2)^3}$
#
# $H_{22} = \frac{\partial^2{R}}{\partial{y^2}} = \frac{2x^2(x^2+y^2)^2 - 2(x^2+y^2)2y(2yx^2)}{(x^2+y^2)^4} = \frac{(x^2+y^2)x^2\left(2(x^2+y^2)-8y^2\right) }{(x^2+y^2)^4} = \frac{2y^2\left(x^2-3y^2\right) }{(x^2+y^2)^3}$
#
# $H_{12} = H_{21} = \frac{\partial^2{R}}{\partial{x}\partial{y}} = \frac{4xy(x^2+y^2)^2 - 2(x^2+y^2)2x(2yx^2)}{(x^2+y^2)^4} = \frac{(x^2+y^2)xy\left(4(x^2+y^2)-8x^2\right) }{(x^2+y^2)^4} = \frac{4xy\left(y^2-x^2\right) }{(x^2+y^2)^3}$
#
# We see that $R=\frac{x^2+2y^2}{x^2+y^2} = 1 + \frac{y^2}{x^2+y^2}$, and it's clear that the minimum is $R=1$ when $y=0$, and the maximum value is $R=2$ when $x=0$.
#
# Take $x=0$ into above derivatives, we have $H = \begin{bmatrix}\frac{-2}{y^2} & 0\\ 0 & \frac{-6}{y^2} \end{bmatrix}$, which is negative definite.
#
# #### Problem VI.1.8
#
# * $\underset{x}{min}\; \underset{y}{max} (x+y) = \underset{x}{min}\infty = \infty$
# * $\underset{x}{max}\; \underset{y}{min} (x+y) = \underset{x}{max}-\infty = -\infty$
#
# #### Problem VI.1.9
#
# * (a) $f(\frac{1}{2}, \frac{1}{2}) \le 0$ because $f(x, y)$  is smooth and convex, and $f(\frac{1}{2}, \frac{1}{2}) = f(\frac{1}{2}(0,1)+\frac{1}{2}(1,0)) \le \frac{1}{2}f(0,1) + \frac{1}{2}f(1,0) = 0$
#
# * (b) The Hessian matrix $H=\begin{bmatrix} a & b \\ b & c\end{bmatrix}$ should be positive semi-definite. so we have $a\ge 0$, and $ac-b^2 \ge 0$.
#
# #### Problem VI.1.10 TODO
#
# Probably yes. A smooth function $f(x,y)$ can be written as the difference $g(x,y) - h(x,y)$ within the circle $x^2+y^2 \le 1$. Not sure how to prove this though.
#
# #### Problem VI.1.11
#
# Take derivative of the formula w.r.t. $x$ and let it equal to 0, we have $\nabla F(x_k)+  \frac{1}{2}\left(H(x_k)+H^T(x_k)\right)(x-x_k) = \nabla F(x_k)+ H(x_k)(x-x_k) = 0 $, it's straight forward to see that $x_{k+1}$ from Newton's method satisfies this condition.
#
# #### Problem VI.1.12
#
# Suppose we start with a point $x_0$, let's expand around this point using Taylor expansion:
# $f(x) = f(x_0) + \frac{df}{dx}(x-x_0) + O((x-x_0)^2)$, we are looking for $x$ such that $f(x)=0$, so if we let $f(x)=0$, we have $x=x_0 - \frac{f(x_0)}{\frac{df}{dx}}$, this point will be closer to the root than $x_0$, so we have an update formula here $x_{k+1}=x_k - \frac{f(x_k)}{\frac{df}{dx}}$
#
# If we run Newton's method on $f(x) = x^2 + 1$, we see the algorithm doesn't converge, it oscillates from left to right of $x=0$.
#
# #### Problem VI.1.13
#
# We can also apply Newton's method to $f(x) = sin(x)$. Depends on the initial value, we get different solutions each time.

# %%
from scipy import optimize
import numpy as np
import math 
import matplotlib.pyplot as plt

def f(x):
    return x**2+1

def df(x):
    return 2*x
    
#root = optimize.newton(f, 1.5, fprime = lambda x: math.cos(x))
#root

def newton(f, df, x0, maxit=500):
    x = x0
    xs, ys = [x0], [f(x0)]
    
    for it in np.arange(maxit):
        x = x - f(x)/df(x)
        if np.abs(f(x)) <= 1.0e-12:
            print('Find the root:', x, f(x), ' at iteration: ', it)
            break
        xs.append(x)
        ys.append(f(x))
    print("Exhausted all ", maxit, " iterations.")
    return x, f(x), xs, ys

print("#### Problem VI.1.12")
v, fv, xs, ys = newton(f, df, 2)

print("#### Problem VI.1.13")
v13, fv13, xs13, ys13 = newton(math.sin, math.cos, 7)
# Out:
# #### Problem VI.1.12
# Exhausted all  500  iterations.
# #### Problem VI.1.13
# Find the root: 6.283185307179586 -2.4492935982947064e-16  at iteration:  3
# Exhausted all  500  iterations.

# %%
plt.plot(xs, ys, '.')

# %% [markdown]
# #### Problem VI.1.14
#
# For a system of equations, e.g.
#
# \begin{align*}
# f_1(x,y) &= 0 \\
# f_2(x,y) &= 0\\
# \end{align*}
#
# If we want to find the roots $(x,y)$ for the two functions, assuming $(x_0, y_0)$ is our initial guess, approximate the equation with Taylor expansion we have
#
# \begin{align*}
# f_1(x,y) &= f_1(x_0, y_0) + \frac{\partial{f_1}}{\partial{x}}|_{(x_0,y_0)}(x-x_0) + \frac{\partial{f_1}}{\partial{y}}|_{(x_0,y_0)}(y-y_0)\\
# f_2(x,y) &= f_2(x_0, y_0) + \frac{\partial{f_2}}{\partial{x}}|_{(x_0,y_0)}(x-x_0) + \frac{\partial{f_2}}{\partial{y}}|_{(x_0,y_0)}(y-y_0)\\
# \end{align*}
#
# Written in matrix format we have
#
# \begin{align*}
# \begin{bmatrix}f_1(x,y) \\ f_2(x,y) \end{bmatrix} &= \begin{bmatrix}f_1(x_0,y_0) \\ f_2(x_0,y_0) \end{bmatrix} + \begin{bmatrix} \frac{\partial{f_1}}{\partial{x}} & \frac{\partial{f_1}}{\partial{y}} \\ \frac{\partial{f_2}}{\partial{x}} & \frac{\partial{f_2}}{\partial{y}} \end{bmatrix}\left(\begin{bmatrix}x \\ y \end{bmatrix} - \begin{bmatrix}x_0 \\ y_0 \end{bmatrix}\right)\\
# \end{align*}
#
# As we are seeking the roots of functions $f_1,f_2$, if $(x,y)$ is the point we are looking for, set $f_1(x,y)=0,f_2(x,y)=0$, we have
#
# \begin{align*}
# \begin{bmatrix}f_1(x_0,y_0) \\ f_2(x_0,y_0) \end{bmatrix} + \begin{bmatrix} \frac{\partial{f_1}}{\partial{x}} & \frac{\partial{f_1}}{\partial{y}} \\ \frac{\partial{f_2}}{\partial{x}} & \frac{\partial{f_2}}{\partial{y}} \end{bmatrix}\left(\begin{bmatrix}x \\ y \end{bmatrix} - \begin{bmatrix}x_0 \\ y_0 \end{bmatrix}\right) &= 0\\
# \begin{bmatrix}x \\ y \end{bmatrix} &= \begin{bmatrix}x_0 \\ y_0 \end{bmatrix} - \begin{bmatrix} \frac{\partial{f_1}}{\partial{x}} & \frac{\partial{f_1}}{\partial{y}} \\ \frac{\partial{f_2}}{\partial{x}} & \frac{\partial{f_2}}{\partial{y}} \end{bmatrix}^{-1}\begin{bmatrix}f_1(x_0,y_0) \\ f_2(x_0,y_0) \end{bmatrix} \\
# \begin{bmatrix}x \\ y \end{bmatrix} &= \begin{bmatrix}x_0 \\ y_0 \end{bmatrix} - J^{-1}\begin{bmatrix}f_1(x_0,y_0) \\ f_2(x_0,y_0) \end{bmatrix}
# \end{align*}
#
# Apply the formula to the equations in problem 14, we compute the Jacobian matrix first:
#
# \begin{align*}
# J & = \begin{bmatrix} \frac{\partial{f_1}}{\partial{u}} & \frac{\partial{f_1}}{\partial{v}} \\ \frac{\partial{f_2}}{\partial{u}} & \frac{\partial{f_2}}{\partial{v}} \end{bmatrix}\\
# &= \begin{bmatrix}3u^2 & -1 \\ -1 & 3v^2\end{bmatrix}\\
# \end{align*}
#
# Thus $J^{-1} = \frac{1}{9u^2v^2-1}\begin{bmatrix}3v^2 & 1 \\ 1 & 3u^2\end{bmatrix}$

# %%
import numpy as np
import math

def newton_m(f, J, x0, maxit=500):
    x = x0
    xs, ys = [x0], [f(x0)]
    
    try:
        for it in np.arange(maxit):
            J1 = np.linalg.inv(J(x))
            x = x - np.matmul(J1, f(x))
            if np.linalg.norm(f(x)) <= 1.0e-12:
                #print('Find the root:', x, f(x), ' at iteration: ', it)
                break
            xs.append(x)
            ys.append(f(x))
    except Exception as e:
        return x, np.array([math.inf, math.inf]), None, None, it
    if it >= maxit:
        print("Exhausted all ", it, " iterations.")
    return x, f(x), xs, ys, it

def f14(x):
    u = x[0]
    v = x[1]
    res = np.array([u**3 -v, v**3 - u])
    return res

def J14(x):
    u = x[0]
    v = x[1]
    res = np.array([[3*u**2, -1], [-1, 3*v**2]])
    return res

print("#### Problem VI.1.14")
solutions = [np.array([0,0]), np.array([1,1]), np.array([-1, -1]), np.array([math.inf, math.inf])]
data_types = {0:[], 1:[], 2:[], 3:[]}
xa = np.arange(-1, 1, 0.01)
ya = np.arange(-1, 1, 0.01)
#xv, yv = np.meshgrid(xa, ya)
for i,x in enumerate(xa):
    for j, y in enumerate(ya):
        x0 = (x,y)
        #print("With initial values: ", x0)
        v, fv, xs, ys, it = newton_m(f14, J14, x0)
        for idx, sol in enumerate(solutions):
            if np.isinf(fv[0]) and np.isinf(fv[1]):
                data_types[3].append(x0)
            elif np.allclose(v, sol):
                data_types[idx].append(x0)
#data_types
# Out:
# #### Problem VI.1.14
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: RuntimeWarning: overflow encountered in double_scalars
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: overflow encountered in matmul
#   # This is added back by InteractiveShellApp.init_path()
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: RuntimeWarning: invalid value encountered in matmul
#   # This is added back by InteractiveShellApp.init_path()
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: RuntimeWarning: overflow encountered in double_scalars
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: RuntimeWarning: invalid value encountered in double_scalars

# %%
import matplotlib.pyplot as plt
colors = ['y','g','b', 'r'] # (0,0), (1,1), (-1,-1), (infty, infty)
for k, x0s in data_types.items():
    #print(x0s)
    xs = [x for x,y in x0s]
    ys = [y for x,y in x0s]
    ys = np.array(ys)
    plt.scatter(xs, ys, c = colors[k], marker='.', s = 0.6)

# %% [markdown]
# #### Problem VI.1.15
#
# $f(\frac{3}{4}x+\frac{1}{4}y) = f(\frac{1}{2}x+\frac{1}{2}(\frac{1}{2}x+\frac{1}{2}y)) \le \frac{1}{2}f(x) + \frac{1}{2}f(\frac{1}{2}x+\frac{1}{2}y) \le \frac{1}{2}f(x) + \frac{1}{2}(\frac{1}{2}f(x)  + \frac{1}{2}f(y)) = \frac{3}{4}f(x) + \frac{1}{4}f(y)$
#
# #### Problem VI.I.16
#
# That's correct by drawing the picture of $f(x) = x^2$.

# %% [markdown]
# #### Problem VI.2.1
#
# * (a) $L(x,\lambda) = \frac{1}{2}x^2_1 + 2x^2_2 + \lambda(x_1 + 3x_2 -b) $
#
# * (b) We have
#   * $\frac{\partial{L}}{\partial{x_1}} = x_1 + \lambda = 0$
#   * $\frac{\partial{L}}{\partial{x_2}} = 4x_2 + 3\lambda = 0$
#   * $\frac{\partial{L}}{\partial{\lambda}} = x_1 + 3x_2 -b = 0$
#
# * (c) We find $x^*_1 = \frac{4}{13}b, x^*_2 = \frac{3}{13}b, \lambda^* = -\frac{4}{13}b$
#
# * (d) TODO
#
# * (e) The minimum cost is $F^* = \frac{2}{13}b^2$, so $\frac{\partial{F^*}}{\partial{b}} = \frac{4}{13}b = -\lambda^*$
#
# #### Problem VI.2.2
#
# $L(x,\lambda) = \frac{1}{2}(x^2_1 + 4x^2_2) + \lambda(2x_1+x_2-5)$, taking derivatives w.r.t. $x_1, x_2, \lambda$, we have
#
# * $\frac{\partial{L}}{\partial{x_1}} = x_1 + 2\lambda = 0$
# * $\frac{\partial{L}}{\partial{x_2}} = 4x_2 + \lambda = 0$
# * $\frac{\partial{L}}{\partial{\lambda}} = 2x_1 + x_2 -5 = 0$
#
# Solve the equations we have $x^*_1 = \frac{40}{17}, x^*_2 = \frac{5}{17}, \lambda^* = -\frac{20}{17}$
#
# #### Problem VI.2.3
#
# Carry out elimination on matrix $M$, we have:
#
# $M=\begin{bmatrix}1 & 0 & 1 \\ 0 & 4 & 3 \\ 1 & 3 & 0 \end{bmatrix} = \begin{bmatrix}1 & 0 & 1 \\ 0 & 4 & 3 \\ 0& 3 & -1\end{bmatrix} = \begin{bmatrix}1 & 0 & 1 \\ 0 & 4 & 3 \\ 0& 0 & -\frac{13}{4}\end{bmatrix}$
#
# Since $S=\begin{bmatrix} 1 & 0 \\ 0 & 4 \end{bmatrix}$, and $A=\begin{bmatrix} 1 \\ 3 \end{bmatrix}$, we have
#
# $-A^TS^{-1}A = -\begin{bmatrix} 1 & 3 \end{bmatrix} \begin{bmatrix} 1 & 0 \\ 0 & \frac{1}{4} \end{bmatrix} \begin{bmatrix} 1 \\ 3 \end{bmatrix} = -\frac{13}{4}$
#
# So it matches the block elimination as well.
#
# There are 2 positive pivots for $M$ and 2 positive eigenvalues for $M$
#
# #### Problem VI.2.4
#
# * (1) $det(LDL^T) = det(L)det(D)det(L^T) = det(L) det(D) det(L) = det(L)^2 det(D)$
#
# $det(Q\Lambda Q^T) = det(Q)det(\Lambda)det(Q^T) = det(Q) det(\Lambda) det(Q) = det(Q)^2 det(\Lambda)$
#
# So we have $det(L)^2 det(D) = det(Q)^2 det(\Lambda)$, which means $det(D)$ and $det(\Lambda)$ have the same sign. If the determinant is negative then $S$ has 1 positive eigenvalue in $\Lambda$ and 1 positive pivot in $D$.
#
# * (2) If the determinant is positive then $S$ could be positive definite or negative definite.  Let $S=\begin{bmatrix}a & b \\ b & c \end{bmatrix}$.
# If both eigenvalues are positive, their product equals to the determinant of $S$, i.e. $det(S) = ac - b^2 > 0$, which also indicate that $ac > b^2 > 0$. Also their sum equals to the trace of $S$, i.e. $trace(S) = a+c > 0$. We conclude that $a>0$ and $c>0$.
#
# If we work out the $S=LDL^T$ decomposition, we see that $S=\begin{bmatrix}1 & 0 \\ \frac{b}{a} & 1 \end{bmatrix} \begin{bmatrix} a & 0 \\ 0 & c - \frac{b^2}{a} \end{bmatrix} \begin{bmatrix} 1 & \frac{b}{a} \\ 0 & 1 \end{bmatrix}$
#
# From the conclusion above, we see the pivots $a$ and $c-\frac{b^2}{a}$ are both larger than 0.
#
# #### Problem VI.2.5
#
# We have with one constraint, $L(x,\lambda) = \frac{1}{2}(x^2_1 + x^2_2 + x^2_3) + \lambda(x_1+x_2+x_3-3)$
#
# * $\frac{\partial{L}}{\partial{x_1}} = x_1 + \lambda = 0$
# * $\frac{\partial{L}}{\partial{x_2}} = x_2 + \lambda = 0$
# * $\frac{\partial{L}}{\partial{x_3}} = x_3 + \lambda = 0$
# * $\frac{\partial{L}}{\partial{\lambda}} = x_1 + x_2 +x_3 -3 = 0$
#
# Solve it we find $x^*_1 = x^*_2 = x^*_3 = 1$ and $\lambda=-1$.
#
# With the second constraint we have $L(x,\lambda_1, \lambda_2) = \frac{1}{2}(x^2_1 + x^2_2 + x^2_3) + \lambda_1(x_1+x_2+x_3-3) + \lambda_2(x_1+2x_2+3x_3 -12)$
#
# * $\frac{\partial{L}}{\partial{x_1}} = x_1 + \lambda_1 + \lambda_2 = 0$
# * $\frac{\partial{L}}{\partial{x_2}} = x_2 + \lambda_1 + 2\lambda_2= 0$
# * $\frac{\partial{L}}{\partial{x_3}} = x_3 + \lambda_1 + 3\lambda_2= 0$
# * $\frac{\partial{L}}{\partial{\lambda_1}} = x_1 + x_2 +x_3 -3 = 0$
# * $\frac{\partial{L}}{\partial{\lambda_2}} = x_1 + 2x_2 +3x_3 -12 = 0$
#
# Solve it we find $x^*_1 = -2, x^*_2 = 1,  x^*_3 =4$ and $\lambda_1=5, \lambda_2 = -3$.
#
# The second minimum value should be less than the first minimum value because any solution that satisfies the two constraints must minimize the function with first constraint as well. If it's larger, that will contradict with whatever the first problem finds.
#
# The first problem has a plane tagent to a sphere in $R^3$, the second problem has a line tagent to a sphere in $R^3$.

# %% [markdown]
# #### Problem VI.3.1
#
# I think $x\ge 0$ is needed in equation (3)  for weak duality because we only know that $(A^Ty)^Tx \le c^Tx$ when $x$ satisfies $Ax=b$ and $x\ge0$.  If $x < 0$, we may not have $(A^Ty)^Tx \le c^Tx$.
#
# #### Problem VI.3.2
#
# The three corners are $(0,0,2), (4,0,0), (0,4,0)$, the point $(0,4,0)$ minimizes $c^Tx$ with a minimum of 12.
#
# #### Problem VI.3.3
#
# In problem 2, we have $c=\begin{bmatrix} 5 \\ 3 \\ 8 \end{bmatrix}$, $A=\begin{bmatrix} 1 & 1 & 2 \end{bmatrix}$, $b=4$. Since there's only 1 constraint in the primal problem, we have 1 variable $y$ in the dual problem, i.e. $y$ is a scalar here. So we need:
#
# \begin{align*}
# \text{Maximize}\; y^Tb \;\;\; \text{subject to} \;\; A^Ty \le c
# \end{align*}
#
# Where we have $A^Ty = \begin{bmatrix} 1 & 1 & 2 \end{bmatrix} y \le \begin{bmatrix} 5 \\ 3 \\ 8 \end{bmatrix}$, we conclude $y\le 3$, the maximum of $y^Tb = yb = 4y$ is $4\times 3 = 12$. This agrees with problem 2 where it finds its minimial of 12.
#
# This demonstrates the duality of the linear programming.
#
# #### Problem VI.3.4 TODO
#
# Let $x_3=x_4=0$, we have $x_1= 4$ and $x_2=2$, the corner is $x=(4,2,0,0)$
#
# How to prove that it costs more than the first corner?
#
# #### Problem VI.3.5
#
# * Payoff matrix 1: the optimal strategy for $X$ to pay the minimial value is to choose row 1. The optimal strategy for $Y$ to get paid max is to choose column 2. So the payoff from $X$ to $Y$ is 2.
#
# * Payoff matrix 2:
#
# If we follow the strategy of the previous payoff matrix. For $X$, on each row, we look at the worst payoff (i.e. maximum payoff), which are 4 and 8 respectively. To optimize $X$'s worst payoff, he will choose row 1 to minimize the maximum payoff, which is 4 here.
#
# Similary, for $Y$, on each row, he'll look at the worst payoff (i.e. minimum payoff), which are 1 and 2 for column 1 and column 2. To optimize $Y$'s worst payoff, he will choose column 2 to maximize the minimum payoff,which is 2 here.
#
# We see that the optimal payoff for $X$ and $Y$ are different in this case, which is not in the first payoff matrix. So it indicates $X$ can't always choose row 1, and $Y$ can't always choose column 2. They need a probability distribution to choose different rows/columns each time.
#
# Suppose $X$ choose the two rows with probabilities $x_1\ge 0,x_2 \ge 0$, and $x_1+x_2 = 1$, then we have a mixed strategy with new row: $x_1+8x_2, 4x_1 + 2x_2$, $X$ will choose $x_1,x_2$ to make the worst payoff as small as possible, i.e. the largest payoff. This will happen when the two largest payoffs are equal: $x_1+8x_2 = 4x_1 + 2x_2$, solve we have $x_1 = \frac{2}{3}, x_2=\frac{1}{3}$. Similarly, we have $y_1 = \frac{2}{9} , y_2 = \frac{7}{9}$. So we see that the optimal payoff is $\frac{10}{3}$, notice this is smaller than 4, if $X$ chooses row 1 and $Y$ chooses column 2.
#
# #### Problem VI.3.6
#
# In an antisymmetric payoff matrix, its diagonal elements are all zero, and for all entries, it has $a_{ij}=-a_{ji}$.
# For $X$, he's going to look at each row, and find the maximum payoff from each row (his worst payoff) and choose the minimum among them. Suppose for a row $i$, we have its maximum of $S_i = \max(a_{i,:})$. So we have maximums from each row of $S_1,S_2,\dots, S_n$, assume the minimum of them is $S_m = \min(S_1,S_2,\dots,S_n)$, that means $X$ will pick row $m$ as his optimal row.
#
# Now we look at $Y$. For $Y$, he needs to look at the worst payoff (minimum payoff) on each column, for a column $a_{:,j}$, since it's antisymmetric matrix, we know that $a_{:,j}=-a_{j,:}$, so $\min(a_{:,j}) = \min(-a_{j,:}) = -\max(a_{j,:}) = -S_j$.
# So for each column, $Y$ gets minimums of $-S_1,-S_2,\dots, -S_n$. Then $Y$ needs to look at the maximum of them, which is $\max(-S_1,-S_2,\dots,-S_n)=-\min(S_1,S_2,\dots,S_n) = -S_m$.
#
# We see that both $X$ and $Y$ are going to pick the row and column with the same index. So their fair payoff will always be on the diagonal, which is always 0.
#
#
# #### Problem VI.3.7
#
# If we have a diagonal matrix $\Sigma$, then the optimal strategy for $X$ will be: On each row, the worst payoff will be $\sigma_i$, among them, the minimum is $\sigma_n$, so he'll choose the last row.
#
# For $Y$, on each column, the minimum payoff will always be 0, so he can choose any column.
#
# So if $X$ always choose the last row, $Y$ will choose the last column to maximize his payoff. So $X$ is better of to have probabilities in choosing the rows to make his worst payoff the same regardless of which row he picks.
#
# Assume the probabilities of picking row $i$ is $x_i$, and we have a mixed row of $\sigma_1x_1,\sigma_2x_2,\dots, \sigma_nx_n$, solve $x_i$ for $\sigma_1x_1 = \sigma_2x_2 = \dots = \sigma_nx_n$, we have $x_i = \frac{1}{\sigma_i}\frac{1}{\sum_k \frac{1}{\sigma_k}}$, so now $X$'s worst payoff will be $\frac{1}{\sum_k \frac{1}{\sigma_k}}$ regardless of his row pick. This payoff is clearly less than the $\sigma_n$ if he always picks the last row.
#
# This is also $Y$'s probabilities to pick the columns.
#
# #### Problem VI.3.8
#
# * $\|(x_1,x_2,x_3)\|_1 = |x_1|+|x_2|+|x_3| \le 2$: if we consider the cases that $x_1,x_2,x_3$ can separately be positive and negative, we see that there are $2^3 = 8$ combinations for the constraint. That is:
#
# \begin{align*}
# x_1 + x_2 + x_3 \le 2 \\
# x_1 + x_2 - x_3 \le 2 \\
# x_1 - x_2 + x_3 \le 2 \\
# x_1 - x_2 - x_3 \le 2 \\
# -x_1 + x_2 + x_3 \le 2 \\
# -x_1 + x_2 - x_3 \le 2 \\
# -x_1 + x_2 + x_3 \le 2 \\
# -x_1 - x_2 - x_3 \le 2 \\
# \end{align*}
#
# $\|x\|_{\infty} \le 2$ is equivalent to $|x_i| \le 2$ for $i=1,2,3$.
#
# \begin{align*}
# x_1 \le 2, x_2 \le2, x_3 \le 2 \\
# x_1 \le 2, x_2 \le2, -x_3 \le 2 \\
# x_1 \le 2, -x_2 \le2, x_3 \le 2 \\
# x_1 \le 2, -x_2 \le2, -x_3 \le 2 \\
# -x_1 \le 2, x_2 \le2, x_3 \le 2 \\
# -x_1 \le 2, x_2 \le2, -x_3 \le 2 \\
# -x_1 \le 2, -x_2 \le2, x_3 \le 2 \\
# -x_1 \le 2, -x_2 \le2, -x_3 \le 2 \\
# \end{align*}
#
# #### Problem VI.3.9 TODO

# %% [markdown]
# #### Problem VI.4.1
#
# $\frac{dF(X)}{dX} = \begin{bmatrix}-\frac{1}{x_{11}}\end{bmatrix}$
# $\frac{d^2F(X)}{dX^2} = \begin{bmatrix}\frac{1}{x^2_{11}}\end{bmatrix}$
#
# #### Problem VI.4.2
#
# If $F(X)=-\log(ad-bc)$, we have $\nabla F = -\frac{1}{det(X)}\nabla det(X) = -X^{-T} = \frac{1}{ad-bc}\begin{bmatrix}-d & b \\ c & -a \end{bmatrix}$, If we have $b=c$, then $\frac{\partial{F}}{\partial{a}} = -\frac{d}{ad-b^2}, \frac{\partial{F}}{\partial{b}} = \frac{2b}{ad-b^2}, \frac{\partial{F}}{\partial{d}} = -\frac{a}{ad-b^2}$
#
# Take second derivatives, we have
#
# \begin{align*}
# \frac{\partial^2{F}}{\partial{a^2}} &= \frac{d^2}{(ad-b^2)^2}\\
# \frac{\partial^2{F}}{\partial{a}\partial{b}} &= -\frac{2bd}{(ad-b^2)^2}\\
# \frac{\partial^2{F}}{\partial{a}\partial{d}} &= \frac{b^2}{(ad-b^2)^2}\\
# \frac{\partial^2{F}}{\partial{b^2}} &= \frac{2ad+2b^2}{(ad-b^2)^2}\\
# \frac{\partial^2{F}}{\partial{b}\partial{d}} &= -\frac{2ab}{(ad-b^2)^2}\\
# \frac{\partial^2{F}}{\partial{d^2}} &= \frac{a^2}{(ad-b^2)^2}\\
# \end{align*}
#
# So we have the 2nd derivative matrix $\nabla^2F = \frac{1}{(ad-b^2)^2}\begin{bmatrix} d^2 & -2bd & b^2 \\ -2bd & 2ad+2b^2 & -2ab \\ b^2 & -2ab & a^2\end{bmatrix}$
#
# Since we assume the matrix $X$ is positive definite, so $ad-b^2 > 0$, $a>0$, so $d>0$ as well. It's easy to check the leading determinants of the 2nd derivative matrix, we have $det(D_1) = d^2> 0$, $(ad-b^2)^2det(D_2) = \frac{2d^2}{ad-b^2} > 0$ and
#
# \begin{align*}
# det(D_3) &= a^2d^2(2ad+2b^2) + 4adb^4 + 4adb^4 - b^4(2ad+2b^2) - 4a^2b^2d^2 - 4a^2b^2d^2 \\
# &= (a^2d^2(2ad+2b^2) - 4a^2b^2d^2) + (4adb^4-4a^2b^2d^2) + (4adb^4 - b^4(2ad+2b^2)) \\
# &= 2a^2d^2(ad-b^2)-4adb^2(ad-b^2)+2b^4(ad-b^2) \\
# &= 2(ad-b^2)(ad-b^2)^2
# \end{align*}
#
# So $det(D_2) = 2(ad-b^2) > 0$. So the second derivative matrix if positive definite as well.
#
# #### Problem VI.4.3
#
# Multiply (7) by $M$ and (8) by $m$, and subtract to remove $\|\nabla f(x_k)\|^2$, we have
#
# \begin{align*}
# Mf(x_{k+1}) - mf(x^*) &\le Mf(x_k) - mf(x_k) \\
# M\left(f(x_{k+1}) - f(x^*)\right) + (M-m)f(x^*) &\le (M-m)f(x_k) \\
# M\left(f(x_{k+1}) - f(x^*)\right) &\le (M-m)\left(f(x_k) - f(x^*)\right) \\
# f(x_{k+1}) - f(x^*) &\le \frac{M-m}{M}\left(f(x_k) - f(x^*)\right) \\
# f(x_{k+1}) - f(x^*) &\le ({1-\frac{m}{M})}\left(f(x_k) - f(x^*)\right) \\
# \end{align*}
#
# #### Problem VI.4.4
#
# OK. What am I supposed to do here?
#
#
#
# #### Problem VI.4.5
# For a projection matrix $\Pi$, we know that $\Pi^T=\Pi$ and $\Pi^2 = \Pi$. So $\Pi$ is symmetric, it can be written as $\Pi=Q\Lambda Q^T$ and $\Pi^2 = \Pi^T\Pi = Q\Lambda^2 Q^T = Q \Lambda Q^T$, so we see that the eigevalues of $\Pi$ are either 1 or zero, so $\lambda_{max} \le 1$.
#
# Now let $y=x-z$, and consider the value of $\frac{y^T\Pi y}{y^Ty}$, its maximum value is the maximum eigenvalue of $\Pi$, meaning $\frac{y^T\Pi y}{y^Ty} \le 1$, take norm on both sides, we have $\|y^T\Pi y\| \le \|y^Ty\|$, that is $\|y^T\Pi^T\Pi y\| \le \|y^Ty\|$, i.e. $\|\Pi y\|^2 \le \|y\|^2$, we have $\|\Pi y \| \le \|y \|$, i.e. $\|\Pi(x-z)\| \le \|x-z\|$.
#
#
# #### Problem VI.4.6
#
# $f(x) = \frac{1}{2}\|Ax-b\|^2 = \frac{1}{2} (Ax-b)^T(Ax-b) = \frac{1}{2} (x^TA^T-b^T)(Ax-b) = \frac{1}{2}(x^TA^TAx-x^TA^Tb -b^TAx + b^Tb)$
#
# Then we have $\nabla f(x_k) = \frac{1}{2}(2A^TAx_k - 2A^Tb) = A^TAx_k - A^Tb$, so $x_{k+1} = x_k - s_k (A^TAx_k - A^Tb)$
